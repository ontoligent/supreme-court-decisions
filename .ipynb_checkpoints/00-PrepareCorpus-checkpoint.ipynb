# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
from lib.helper import lmplot, Db
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Graphics

# %%
sns.set()

# %%
fig = plt.gcf()
fig.set_size_inches(12, 8)

# %% [markdown]
# # Config

# %%
base_path = ''
data_in   = f'{base_path}src'
data_out  = f'{base_path}db'
db_file = f'{data_out}/ussc.db'

# %%
db = Db(db_file)

# %%
csv = pd.read_csv(f'{data_in}/ussc_data.csv')
csv.columns = csv.columns.str.lower().str.replace(' ', '_')
csv['case_id'] = csv.filename.apply(lambda x: x.split('.')[0])

# %%
# csv

# %% [markdown]
# # Get column groups

# %%
concur_cols       = [x for x in csv.columns[csv.columns.str.match('^concur_\d$')]]
concur_auth_cols  = [x for x in csv.columns[csv.columns.str.match('^concur_\d_.+$')]]
dissent_cols      = [x for x in csv.columns[csv.columns.str.match('^dissent_\d$')]]
dissent_auth_cols = [x for x in csv.columns[csv.columns.str.match('^dissent_\d_.+$')]]
case_cols         = set(csv.columns) - set(concur_cols) - set(dissent_cols) - set(concur_auth_cols) - set(dissent_auth_cols) - {'opinion', 'opinion_author'}

# %% [markdown]
# # Create CASE table

# %%
db.add_table('CASE', csv[case_cols])

# %%
db.tables
# Out:
# ['CASE']

# %%
# db.CASE = csv[case_cols]
db.CASE = db.CASE.join(db.CASE.case_id.str.split('_').to_frame()\
            .case_id.apply(pd.Series)[[0, 2]]\
            .rename(columns={0:'vol_num',2:'case_num'}))
db.CASE['vol_num'] = db.CASE.vol_num.astype('int')
db.CASE['case_num'] = db.CASE.case_num.astype('int')
db.CASE = db.CASE.set_index(['vol_num','case_num']).sort_index()
db.CASE = db.CASE.drop(['index','court','filename','case_id'], axis=1)

# %%
db.CASE
# Out:
#                           full_date  year
# vol_num case_num
# 3       1          February 7, 1794  1794
#         6         February 18, 1794  1794
#         17        February 20, 1795  1795
#         121             AUGUST 1795  1795
#         171           March 8, 1796  1796
# ...                             ...   ...
# 554     407           June 25, 2008  2008
#         471           June 26, 2008  2008
#         527           June 26, 2008  2008
#         570           June 26, 2008  2008
#         724           June 26, 2008  2008
#
# [22115 rows x 2 columns]

# %%
db.CASE['justia_url'] = db.CASE.apply(lambda x: f"https://supreme.justia.com/cases/federal/us/{x.name[0]}/{x.name[1]}/", 1)

# %%
db.CASE.head()
# Out:
#                           full_date  year  \
# vol_num case_num
# 3       1          February 7, 1794  1794
#         6         February 18, 1794  1794
#         17        February 20, 1795  1795
#         121             AUGUST 1795  1795
#         171           March 8, 1796  1796
#
#                                                          justia_url
# vol_num case_num
# 3       1          https://supreme.justia.com/cases/federal/us/3/1/
#         6          https://supreme.justia.com/cases/federal/us/3/6/
#         17        https://supreme.justia.com/cases/federal/us/3/17/
#         121       https://supreme.justia.com/cases/federal/us/3/...
#         171       https://supreme.justia.com/cases/federal/us/3/...

# %% [markdown]
# # Create CORPUS table (of opinions)

# %%
content_cols = ['opinion'] + concur_cols + dissent_cols
author_cols = ['opinion_author'] + concur_auth_cols + dissent_auth_cols
dfs = []
for x, y in zip(author_cols, content_cols):
    df = csv[['year','case_id', x, y]].copy()
    df = df.rename(columns={x:'author_id', y:'opinion'})
    df['position'] = x.split('_')[0]
    df = df.dropna()
    dfs.append(df)
db.add_table('CORPUS', pd.concat(dfs))
del(dfs)

# %%
db.CORPUS.head()
# Out:
#    year     case_id    author_id  \
# 0  1924  266_US_342         TAFT
# 1  1914   233_US_16      WHITE_E
# 2  1943  318_US_350  FRANKFURTER
# 3  1866    70_US_37        FIELD
# 4  1983  460_US_428     BLACKMUN
#
#                                              opinion position
# 0  MR. CHIEF JUSTICE TAFT delivered the opinion o...  opinion
# 1  MR. CHIEF JUSTICE WHITE delivered the opinion ...  opinion
# 2  MR. JUSTICE FRANKFURTER delivered the opinion ...  opinion
# 3  Mr. Justice FIELD delivered the opinion of the...  opinion
# 4  JUSTICE BLACKMUN delivered the opinion of the ...  opinion

# %%
db.CORPUS['doc_len'] = db.CORPUS.opinion.str.len()
db.CORPUS[['vol_num','case_num']] = db.CORPUS.apply(lambda x: pd.Series(x.case_id.split('_')), 1)[[0,2]]
db.CORPUS.vol_num = db.CORPUS.vol_num.astype('int')
db.CORPUS.case_num = db.CORPUS.case_num.astype('int')

# %%
db.CORPUS.head()
# Out:
#    year     case_id    author_id  \
# 0  1924  266_US_342         TAFT
# 1  1914   233_US_16      WHITE_E
# 2  1943  318_US_350  FRANKFURTER
# 3  1866    70_US_37        FIELD
# 4  1983  460_US_428     BLACKMUN
#
#                                              opinion position  doc_len  \
# 0  MR. CHIEF JUSTICE TAFT delivered the opinion o...  opinion    14556
# 1  MR. CHIEF JUSTICE WHITE delivered the opinion ...  opinion     9783
# 2  MR. JUSTICE FRANKFURTER delivered the opinion ...  opinion    10861
# 3  Mr. Justice FIELD delivered the opinion of the...  opinion     8867
# 4  JUSTICE BLACKMUN delivered the opinion of the ...  opinion    34278
#
#    vol_num  case_num
# 0      266       342
# 1      233        16
# 2      318       350
# 3       70        37
# 4      460       428

# %%
db.CORPUS = db.CORPUS.reset_index().set_index(['vol_num','case_num','author_id']).sort_index()
db.CORPUS = db.CORPUS[['year','position','opinion','doc_len']]

# %%
db.CORPUS
# Out:
#                                year position  \
# vol_num case_num author_id
# 3       1        JAY           1794  opinion
#         6        JAY           1794  opinion
#         17       WILSON        1795  opinion
#         121      RUTLEDGE_J    1795  opinion
#         171      CHASE_SALMON  1796  opinion
# ...                             ...      ...
# 554     570      SCALIA        2008  opinion
#                  STEVENS       2008  dissent
#         724      ALITO         2008  opinion
#                  GINSBURG      2008   concur
#                  STEVENS       2008   concur
#
#                                                                          opinion  \
# vol_num case_num author_id
# 3       1        JAY           The argument having continued for four days, t...
#         6        JAY           BY THE COURT: The Judges being decidedly of op...
#         17       WILSON        WILSON, Justice. The recognizance must be take...
#         121      RUTLEDGE_J    By the COURT: -- We have consulted together on...
#         171      CHASE_SALMON  THE COURT delivered their opinions seriatim in...
# ...                                                                          ...
# 554     570      SCALIA        Justice Scalia delivered the opinion of the Co...
#                  STEVENS       DISSENT BY: STEVENS; BREYER \nDISSENT \nJustic...
#         724      ALITO         Justice Alito delivered the opinion of the Cou...
#                  GINSBURG      Justice Ginsburg, with whom Justice Breyer joi...
#                  STEVENS       CONCUR BY: Stevens (In Part); Ginsburg (In Par...
#
#                                doc_len
# vol_num case_num author_id
# 3       1        JAY              5712
#         6        JAY              2028
#         17       WILSON           2035
#         121      RUTLEDGE_J       8452
#         171      CHASE_SALMON     7826
# ...                                ...
# 554     570      SCALIA         107923
#                  STEVENS         62664
#         724      ALITO           40590
#                  GINSBURG         1253
#                  STEVENS         16154
#
# [34228 rows x 4 columns]

# %% [markdown]
# # Create AUTHOR table
#
# NB: The `author_id` column is non-atomic.

# %%
# db.AUTHOR = db.CORPUS.reset_index()[['author_id','position']].value_counts().to_frame('n').unstack(fill_value=0)
db.add_table('AUTHOR', db.CORPUS.reset_index()[['author_id','position']].value_counts().to_frame('n').unstack(fill_value=0))
db.AUTHOR.columns = db.AUTHOR.columns.droplevel(0)
db.AUTHOR.columns.name = ''

# %%
db.AUTHOR['n_authors'] = db.AUTHOR.apply(lambda x: len(x.name.split()), 1)
db.AUTHOR['n_opinions'] = db.AUTHOR[['opinion','concur','dissent']].sum(1)

# %%
db.AUTHOR.head()
# Out:
#                              concur  dissent  opinion  n_authors  n_opinions
# author_id
# ALITO                            10       13       17          1          40
# BALDWIN                           4       35       39          1          78
# BARBOUR                           0        3       17          1          20
# BLACK                           186      330      498          1        1014
# BLACK CHIEF_JUSTICE DOUGLAS       1        0        0          3           1

# %%
db.AUTHOR.n_authors.value_counts().sort_index().plot.bar(rot=0);

# %%
db.AUTHOR.n_authors.value_counts().sort_index().plot.pie();

# %% [markdown]
# # AUTHOR Success
#
# An experimental way of measuring the success of a judge.

# %%
db.AUTHOR['success'] = np.log((((db.AUTHOR.concur + db.AUTHOR.opinion + 1) / (db.AUTHOR.dissent + 1)) * (db.AUTHOR.n_opinions + 2)))

# %%
db.AUTHOR.sort_values('success', ascending=False).head(20).style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_223e9_row0_col0,#T_223e9_row0_col1,#T_223e9_row1_col0,#T_223e9_row1_col3,#T_223e9_row2_col3,#T_223e9_row3_col3,#T_223e9_row4_col3,#T_223e9_row5_col3,#T_223e9_row6_col3,#T_223e9_row7_col3,#T_223e9_row8_col3,#T_223e9_row9_col3,#T_223e9_row10_col3,#T_223e9_row11_col3,#T_223e9_row12_col3,#T_223e9_row13_col2,#T_223e9_row13_col3,#T_223e9_row13_col4,#T_223e9_row14_col3,#T_223e9_row15_col3,#T_223e9_row16_col3,#T_223e9_row17_col3,#T_223e9_row18_col3,#T_223e9_row19_col3,#T_223e9_row19_col5{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_223e9_row0_col2{
#             background-color:  #4897c4;
#             color:  #000000;
#         }#T_223e9_row0_col3,#T_223e9_row0_col5,#T_223e9_row4_col2,#T_223e9_row4_col4,#T_223e9_row16_col0,#T_223e9_row16_col1{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_223e9_row0_col4{
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }#T_223e9_row1_col1{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_223e9_row1_col2,#T_223e9_row6_col2{
#             background-color:  #afc1dd;
#             color:  #000000;
#         }#T_223e9_row1_col4,#T_223e9_row3_col2{
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }#T_223e9_row1_col5,#T_223e9_row16_col2{
#             background-color:  #79abd0;
#             color:  #000000;
#         }#T_223e9_row2_col0,#T_223e9_row3_col0,#T_223e9_row19_col0{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_223e9_row2_col1,#T_223e9_row15_col5,#T_223e9_row16_col5{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_223e9_row2_col2{
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }#T_223e9_row2_col4{
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }#T_223e9_row2_col5,#T_223e9_row9_col2{
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }#T_223e9_row3_col1,#T_223e9_row5_col0,#T_223e9_row11_col0,#T_223e9_row14_col0{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_223e9_row3_col4,#T_223e9_row15_col2{
#             background-color:  #c9cee4;
#             color:  #000000;
#         }#T_223e9_row3_col5{
#             background-color:  #b0c2de;
#             color:  #000000;
#         }#T_223e9_row4_col0{
#             background-color:  #0567a2;
#             color:  #f1f1f1;
#         }#T_223e9_row4_col1{
#             background-color:  #034b76;
#             color:  #f1f1f1;
#         }#T_223e9_row4_col5{
#             background-color:  #cccfe5;
#             color:  #000000;
#         }#T_223e9_row5_col1{
#             background-color:  #a4bcda;
#             color:  #000000;
#         }#T_223e9_row5_col2{
#             background-color:  #63a2cb;
#             color:  #000000;
#         }#T_223e9_row5_col4{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_223e9_row5_col5,#T_223e9_row8_col2,#T_223e9_row17_col2,#T_223e9_row17_col4{
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }#T_223e9_row6_col0,#T_223e9_row13_col0{
#             background-color:  #e2dfee;
#             color:  #000000;
#         }#T_223e9_row6_col1{
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }#T_223e9_row6_col4{
#             background-color:  #b5c4df;
#             color:  #000000;
#         }#T_223e9_row6_col5{
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }#T_223e9_row7_col0{
#             background-color:  #03476f;
#             color:  #f1f1f1;
#         }#T_223e9_row7_col1{
#             background-color:  #046198;
#             color:  #f1f1f1;
#         }#T_223e9_row7_col2{
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }#T_223e9_row7_col4{
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }#T_223e9_row7_col5{
#             background-color:  #dfddec;
#             color:  #000000;
#         }#T_223e9_row8_col0,#T_223e9_row12_col4{
#             background-color:  #eee8f3;
#             color:  #000000;
#         }#T_223e9_row8_col1,#T_223e9_row11_col4{
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }#T_223e9_row8_col4{
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }#T_223e9_row8_col5{
#             background-color:  #e0deed;
#             color:  #000000;
#         }#T_223e9_row9_col0,#T_223e9_row11_col2,#T_223e9_row17_col0{
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }#T_223e9_row9_col1{
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }#T_223e9_row9_col4{
#             background-color:  #a2bcda;
#             color:  #000000;
#         }#T_223e9_row9_col5{
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }#T_223e9_row10_col0,#T_223e9_row15_col0,#T_223e9_row18_col0{
#             background-color:  #4295c3;
#             color:  #000000;
#         }#T_223e9_row10_col1{
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }#T_223e9_row10_col2{
#             background-color:  #2786bb;
#             color:  #000000;
#         }#T_223e9_row10_col4{
#             background-color:  #2182b9;
#             color:  #000000;
#         }#T_223e9_row10_col5{
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }#T_223e9_row11_col1,#T_223e9_row12_col1{
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }#T_223e9_row11_col5{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_223e9_row12_col0,#T_223e9_row14_col5{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_223e9_row12_col2{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_223e9_row12_col5{
#             background-color:  #ede8f3;
#             color:  #000000;
#         }#T_223e9_row13_col1{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_223e9_row13_col5{
#             background-color:  #f5eef6;
#             color:  #000000;
#         }#T_223e9_row14_col1,#T_223e9_row17_col1{
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }#T_223e9_row14_col2{
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }#T_223e9_row14_col4{
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }#T_223e9_row15_col1{
#             background-color:  #96b6d7;
#             color:  #000000;
#         }#T_223e9_row15_col4{
#             background-color:  #c1cae2;
#             color:  #000000;
#         }#T_223e9_row16_col4{
#             background-color:  #569dc8;
#             color:  #000000;
#         }#T_223e9_row17_col5{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_223e9_row18_col1{
#             background-color:  #04588a;
#             color:  #f1f1f1;
#         }#T_223e9_row18_col2{
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }#T_223e9_row18_col4{
#             background-color:  #7bacd1;
#             color:  #000000;
#         }#T_223e9_row18_col5{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_223e9_row19_col1{
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }#T_223e9_row19_col2,#T_223e9_row19_col4{
#             background-color:  #e1dfed;
#             color:  #000000;
#         }</style><table id="T_223e9_" ><thead>    <tr>        <th class="index_name level0" ></th>        <th class="col_heading level0 col0" >concur</th>        <th class="col_heading level0 col1" >dissent</th>        <th class="col_heading level0 col2" >opinion</th>        <th class="col_heading level0 col3" >n_authors</th>        <th class="col_heading level0 col4" >n_opinions</th>        <th class="col_heading level0 col5" >success</th>    </tr>    <tr>        <th class="index_name level0" >author_i

# %%
db.AUTHOR.success.hist();

# %%
sns.histplot(data=db.AUTHOR, x='success', stat='count', kde=True);

# %% [markdown]
# # Add stat features to CASE

# %%
db.CASE['opinion_count'] = db.CORPUS.reset_index().groupby(['vol_num','case_num'])['position'].count().sort_values(ascending=False).to_frame()
db.CASE[['concur','dissent','opinion']] = db.CORPUS.groupby(['vol_num','case_num','position']).position.count().to_frame().unstack(fill_value=0)
db.CASE['doc_len_sum'] = db.CORPUS.groupby(['vol_num','case_num']).doc_len.sum()

# %%
db.CASE.describe().T
# Out:
#                  count          mean           std     min     25%      50%  \
# year           22115.0   1923.464707     46.272354  1789.0  1896.0   1923.0
# opinion_count  22115.0      1.548903      0.911670     1.0     1.0      1.0
# concur         22115.0      0.205517      0.550059     0.0     0.0      0.0
# dissent        22115.0      0.342211      0.612645     0.0     0.0      0.0
# opinion        22115.0      1.001176      0.034269     1.0     1.0      1.0
# doc_len_sum    22115.0  20002.719783  22836.842285    64.0  6793.0  13037.0
#
#                    75%       max
# year            1961.0    2008.0
# opinion_count      2.0       9.0
# concur             0.0       6.0
# dissent            1.0       4.0
# opinion            1.0       2.0
# doc_len_sum    24939.5  631307.0

# %%
db.CASE.head()
# Out:
#                           full_date  year  \
# vol_num case_num
# 3       1          February 7, 1794  1794
#         6         February 18, 1794  1794
#         17        February 20, 1795  1795
#         121             AUGUST 1795  1795
#         171           March 8, 1796  1796
#
#                                                          justia_url  \
# vol_num case_num
# 3       1          https://supreme.justia.com/cases/federal/us/3/1/
#         6          https://supreme.justia.com/cases/federal/us/3/6/
#         17        https://supreme.justia.com/cases/federal/us/3/17/
#         121       https://supreme.justia.com/cases/federal/us/3/...
#         171       https://supreme.justia.com/cases/federal/us/3/...
#
#                   opinion_count  concur  dissent  opinion  doc_len_sum
# vol_num case_num
# 3       1                     1       0        0        1         5712
#         6                     1       0        0        1         2028
#         17                    1       0        0        1         2035
#         121                   1       0        0        1         8452
#         171                   5       3        1        1        30900

# %%
db.CASE.sort_values('opinion_count', ascending=False).head()
# Out:
#                       full_date  year  \
# vol_num case_num
# 60      393       March 5, 1857  1857
# 530     914       June 28, 2000  2000
# 343     579        June 2, 1952  1952
# 399     1         June 22, 1970  1970
# 433     425       June 28, 1977  1977
#
#                                                          justia_url  \
# vol_num case_num
# 60      393       https://supreme.justia.com/cases/federal/us/60...
# 530     914       https://supreme.justia.com/cases/federal/us/53...
# 343     579       https://supreme.justia.com/cases/federal/us/34...
# 399     1         https://supreme.justia.com/cases/federal/us/39...
# 433     425       https://supreme.justia.com/cases/federal/us/43...
#
#                   opinion_count  concur  dissent  opinion  doc_len_sum
# vol_num case_num
# 60      393                   9       6        2        1       631307
# 530     914                   8       3        4        1       189109
# 343     579                   7       5        1        1       168301
# 399     1                     7       3        3        1        43105
# 433     425                   7       4        2        1       202805

# %%
db.CASE.sort_values('doc_len_sum', ascending=False).head()
# Out:
#                        full_date  year  \
# vol_num case_num
# 60      393        March 5, 1857  1857
# 67      17        March 10, 1863  1863
# 367     1           June 5, 1961  1961
# 182     244         May 27, 1901  1901
# 79      457          May 1, 1871  1871
#
#                                                          justia_url  \
# vol_num case_num
# 60      393       https://supreme.justia.com/cases/federal/us/60...
# 67      17        https://supreme.justia.com/cases/federal/us/67...
# 367     1         https://supreme.justia.com/cases/federal/us/36...
# 182     244       https://supreme.justia.com/cases/federal/us/18...
# 79      457       https://supreme.justia.com/cases/federal/us/79...
#
#                   opinion_count  concur  dissent  opinion  doc_len_sum
# vol_num case_num
# 60      393                   9       6        2        1       631307
# 67      17                    3       0        2        1       494184
# 367     1                     5       0        4        1       329506
# 182     244                   6       3        2        1       320133
# 79      457                   5       1        3        1       317507

# %%
db.CASE['has_dissent'] = db.CASE.dissent.astype('bool').astype('int')

# %%
db.CASE.head()
# Out:
#                           full_date  year  \
# vol_num case_num
# 3       1          February 7, 1794  1794
#         6         February 18, 1794  1794
#         17        February 20, 1795  1795
#         121             AUGUST 1795  1795
#         171           March 8, 1796  1796
#
#                                                          justia_url  \
# vol_num case_num
# 3       1          https://supreme.justia.com/cases/federal/us/3/1/
#         6          https://supreme.justia.com/cases/federal/us/3/6/
#         17        https://supreme.justia.com/cases/federal/us/3/17/
#         121       https://supreme.justia.com/cases/federal/us/3/...
#         171       https://supreme.justia.com/cases/federal/us/3/...
#
#                   opinion_count  concur  dissent  opinion  doc_len_sum  \
# vol_num case_num
# 3       1                     1       0        0        1         5712
#         6                     1       0        0        1         2028
#         17                    1       0        0        1         2035
#         121                   1       0        0        1         8452
#         171                   5       3        1        1        30900
#
#                   has_dissent
# vol_num case_num
# 3       1                   0
#         6                   0
#         17                  0
#         121                 0
#         171                 1

# %%
sns.relplot(data=db.CASE.reset_index(), 
            x='year', 
            y='doc_len_sum',            
            hue='has_dissent', 
            size='opinion_count',
            aspect=2.5);

# %% [markdown]
# # Look at CASE volume over time

# %%
# db.YEAR = db.CORPUS.groupby(['year']).doc_len.sum().to_frame('doc_len_sum')
db.add_table('YEAR', db.CORPUS.groupby(['year']).doc_len.sum().to_frame('doc_len_sum'))
db.YEAR['doc_len_mean'] = db.CORPUS.groupby(['year']).doc_len.mean()
db.YEAR['opinion_count'] = db.CORPUS.groupby(['year']).opinion.count()

# %%
db.YEAR.head()
# Out:
#       doc_len_sum  doc_len_mean  opinion_count
# year
# 1789        38585  12861.666667              3
# 1794         7740   3870.000000              2
# 1795        10487   5243.500000              2
# 1796        51193   5119.300000             10
# 1797        21407   5351.750000              4

# %%
sns.relplot(data=db.YEAR.reset_index(), x='year', y='doc_len_mean', size='opinion_count', hue='doc_len_sum', aspect=2.5);

# %%
sns.relplot(data=db.YEAR.reset_index(), x='year', y='opinion_count', hue='doc_len_mean', size='doc_len_sum', aspect=2.5);

# %%
P = lmplot(db.YEAR.reset_index()).set_order(6).set_x('year');

# %%
P.set_y('opinion_count').plot()

# %%
P.set_y('doc_len_sum').plot()

# %%
P.set_y('doc_len_mean').plot()

# %%
P.set_x('opinion_count').set_y('doc_len_sum').set_order(1).plot()

# %%
P.set_x('opinion_count').set_y('doc_len_mean').plot()

# %%
P.set_x('doc_len_sum').set_y('doc_len_mean').set_order(1).plot()

# %% [markdown]
# # Consolidate data by opinion
#
# Keep those with both opinion and dissent.

# %%
M = db.CORPUS.groupby(['vol_num','case_num','position']).opinion.apply(lambda x: ' '.join(x)).to_frame().sort_index()

# %%
M.head()
# Out:
#                                                                      opinion
# vol_num case_num position
# 3       1        opinion   The argument having continued for four days, t...
#         6        opinion   BY THE COURT: The Judges being decidedly of op...
#         17       opinion   WILSON, Justice. The recognizance must be take...
#         121      opinion   By the COURT: -- We have consulted together on...
#         171      concur    IREDELL. Justice. -- I agree in opinion with m...

# %%
M1 = M.unstack()
M1.columns = M1.columns.droplevel(0)

# %%
M1.head()
# Out:
# position                                                     concur  \
# vol_num case_num
# 3       1                                                       NaN
#         6                                                       NaN
#         17                                                      NaN
#         121                                                     NaN
#         171       IREDELL. Justice. -- I agree in opinion with m...
#
# position                                                    dissent  \
# vol_num case_num
# 3       1                                                       NaN
#         6                                                       NaN
#         17                                                      NaN
#         121                                                     NaN
#         171       DISSENT BY: CUSHING\nCUSHING, Justice. As I ha...
#
# position                                                    opinion
# vol_num case_num
# 3       1         The argument having continued for four days, t...
#         6         BY THE COURT: The Judges being decidedly of op...
#         17        WILSON, Justice. The recognizance must be take...
#         121       By the COURT: -- We have consulted together on...
#         171       THE COURT delivered their opinions seriatim in...

# %%
# M2 = M1[['opinion','dissent']].stack().to_frame('doc_content')

# %%
# db.CORPUS_COMPRESSED = M1[(~M1.dissent.isna()) & (~M1.opinion.isna())][['opinion','dissent']].stack().to_frame('doc_content')

# %%
db.add_table('CORPUS_COMPRESSED', M1[(~M1.dissent.isna()) & (~M1.opinion.isna())][['opinion','dissent']].stack().to_frame('doc_content'))

# %%
db.CORPUS_COMPRESSED
# Out:
#                                                                  doc_content
# vol_num case_num position
# 3       171      opinion   THE COURT delivered their opinions seriatim in...
#                  dissent   DISSENT BY: CUSHING\nCUSHING, Justice. As I ha...
#         321      opinion   ELSWORTH, Chief Justice. The question, how far...
#                  dissent   DISSENT BY: WILSON\nWILSON, Justice. I conside...
#         386      opinion   CHASE, Justice. The decision of one question d...
# ...                                                                      ...
# 554     471      dissent   DISSENT BY: Stevens (In Part); Ginsburg (In Pa...
#         527      opinion   Justice Scalia delivered the opinion of the Co...
#                  dissent   DISSENT BY: Stevens \nDISSENT \nJustice Steven...
#         570      opinion   Justice Scalia delivered the opinion of the Co...
#                  dissent   Justice Breyer, with whom Justice Stevens, Jus...
#
# [12348 rows x 1 columns]

# %%
db.CORPUS_COMPRESSED['doc_len'] = db.CORPUS_COMPRESSED.doc_content.str.len()

# %%
db.CORPUS_COMPRESSED.groupby('position').doc_len.mean().plot.pie();

# %% [markdown]
# # Export

# %%
db.save_all_tables()
# Out:
# Saving CASE
# Saving CORPUS
# Saving AUTHOR
# Saving YEAR
# Saving CORPUS_COMPRESSED
